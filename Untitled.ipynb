# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataframe = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
dataframe
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
dataframe.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
dataframe.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
dataframe["Department"].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
dataframe["BusinessTravel"] =dataframe["BusinessTravel"].astype('category').cat.codes

# %%
# dataframe["Attrition"] =dataframe["Attrition"].astype('category').cat.codes
# dataframe["Department"] =dataframe["Department"].astype('category').cat.codes
# dataframe["EducationField"] =dataframe["EducationField"].astype('category').cat.codes
# dataframe["Gender"] =dataframe["Gender"].astype('category').cat.codes
# dataframe["JobRole"] =dataframe["JobRole"].astype('category').cat.codes
# dataframe["MaritalStatus"] =dataframe["MaritalStatus"].astype('category').cat.codes
# dataframe["Over18"] =dataframe["Over18"].astype('category').cat.codes
# dataframe["OverTime"] =dataframe["OverTime"].astype('category').cat.codes

# %%
# for column in dataframe.columns:
#     print("Correlations between Attrition and ",column," is: ", dataframe["Attrition"].corr(dataframe[column]))

# %%
sns.catplot(x= "Attrition", y = "Age", data = dataframe)

# %%
sns.catplot(x= "Attrition", y = "DailyRate", data = dataframe)

# %%
sns.catplot(x= "Attrition", y = "DistanceFromHome", data = dataframe)

# %%
sns.catplot(x= "Attrition", y = "HourlyRate", data = dataframe)

# %%
sns.catplot(x= "Attrition", y = "MonthlyIncome", data = dataframe)

# %%
sns.catplot(x= "Attrition", y = "MonthlyRate", data = dataframe)

# %%
sns.catplot(x= "Attrition", y = "NumCompaniesWorked", data = dataframe)

# %%
df2=dataframe[["JobRole","Attrition"]]

# %%
df2
# Out:
#                         JobRole Attrition
# 0               Sales Executive       Yes
# 1            Research Scientist        No
# 2         Laboratory Technician       Yes
# 3            Research Scientist        No
# 4         Laboratory Technician        No
# ...                         ...       ...
# 1465      Laboratory Technician        No
# 1466  Healthcare Representative        No
# 1467     Manufacturing Director        No
# 1468            Sales Executive        No
# 1469      Laboratory Technician        No
#
# [1470 rows x 2 columns]

# %%
df3=dataframe[["Attrition", "DistanceFromHome"]]

# %%
df3.groupby(["Attrition"]).mean()
# Out:
#            DistanceFromHome
# Attrition
# No                 8.915653
# Yes               10.632911

# %%
df3.groupby(["Attrition"]).median()
# Out:
#            DistanceFromHome
# Attrition
# No                      7.0
# Yes                     9.0

# %%
sns.barplot(data =dataframe, x = "Attrition", y="DistanceFromHome" , hue="JobRole")
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='DistanceFromHome'>

# %%
dataframe["Education"]
# Out:
# 0       2
# 1       1
# 2       2
# 3       4
# 4       1
#        ..
# 1465    2
# 1466    1
# 1467    3
# 1468    3
# 1469    3
# Name: Education, Length: 1470, dtype: int64

# %%
df4 = dataframe[["Education","MonthlyIncome"]]

# %%
df4.describe()
# Out:
#          Education  MonthlyIncome
# count  1470.000000    1470.000000
# mean      2.912925    6502.931293
# std       1.024165    4707.956783
# min       1.000000    1009.000000
# 25%       2.000000    2911.000000
# 50%       3.000000    4919.000000
# 75%       4.000000    8379.000000
# max       5.000000   19999.000000

# %%
df4.groupby(["Education"]).mean()
# Out:
#            MonthlyIncome
# Education
# 1            5640.570588
# 2            6226.645390
# 3            6517.263986
# 4            6832.402010
# 5            8277.645833

# %%
sns.barplot(x="Education", y="MonthlyIncome",data=df4)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='MonthlyIncome'>

# %%
df5 = dataframe[["Education","Attrition","MonthlyIncome"]]

# %%
sns.barplot(x="Education", y="MonthlyIncome",hue="Attrition",data=df5)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='MonthlyIncome'>
